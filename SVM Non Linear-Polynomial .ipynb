# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(font_scale=1.2)
import pandas as pd

# %%
sna_data = pd.read_csv('Social_Network_Ads.csv')
x = dataset.iloc[:, [2,3]].values
y = dataset.iloc[:, -1].values
sna_data.head(10)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0
# 6  15598044  Female   27            84000          0
# 7  15694829  Female   32           150000          1
# 8  15600575    Male   25            33000          0
# 9  15727311  Female   35            65000          0

# %%
sna_data.shape
# Out:
# (400, 5)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 0)

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='poly', degree=8)
svclassifier.fit(x_train, y_train)
# Out:
# SVC(degree=8, kernel='poly')

# %%
y_pred = svclassifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
sna_cm = confusion_matrix(y_test, y_pred)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[56  2]
#  [16  6]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.97      0.86        58
#            1       0.75      0.27      0.40        22
#
#     accuracy                           0.78        80
#    macro avg       0.76      0.62      0.63        80
# weighted avg       0.77      0.78      0.73        80

# %%
import seaborn as sn
sn.heatmap(sna_cm, annot=True,annot_kws={"size": 16})
# Out:
# <AxesSubplot:>

# %%
plt.plot(x_test,y_test)
# Out:
# [<matplotlib.lines.Line2D at 0x1713f4a6760>,
#  <matplotlib.lines.Line2D at 0x1713f4a6820>]

# %%
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-58-4bb1262ee0c4> in <module>
#       2 from matplotlib.colors import ListedColormap
#       3 x_test, y_test = x_train, y_train
# ----> 4 X1, X2 = np.meshgrid(np.arange(start = x_test[:, 0].min() - 1, stop = x_test[:, 0].max() + 1, step = 0.01),
#       5                      np.arange(start = x_test[:, 1].min() - 1, stop = x_test[:, 1].max() + 1, step = 0.01))
#       6 plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
#
# <__array_function__ internals> in meshgrid(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in meshgrid(copy, sparse, indexing, *xi)
#    4299
#    4300     if copy:
# -> 4301         output = [x.copy() for x in output]
#    4302
#    4303     return output
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in <listcomp>(.0)
#    4299
#    4300     if copy:
# -> 4301         output = [x.copy() for x in output]
#    4302
#    4303     return output
#
# MemoryError: Unable to allocate 443. GiB for an array with shape (13500200, 4400) and data type float64
