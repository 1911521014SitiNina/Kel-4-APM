# %% [markdown]
# <a href="https://colab.research.google.com/github/1911521014SitiNina/Kel-4-APM/blob/main/Decision_Regresi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv(r'IRIS.csv')
iris.head(60)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 0            5.1          3.5           1.4          0.2      Iris-setosa
# 1            4.9          3.0           1.4          0.2      Iris-setosa
# 2            4.7          3.2           1.3          0.2      Iris-setosa
# 3            4.6          3.1           1.5          0.2      Iris-setosa
# 4            5.0          3.6           1.4          0.2      Iris-setosa
# 5            5.4          3.9           1.7          0.4      Iris-setosa
# 6            4.6          3.4           1.4          0.3      Iris-setosa
# 7            5.0          3.4           1.5          0.2      Iris-setosa
# 8            4.4          2.9           1.4          0.2      Iris-setosa
# 9            4.9          3.1           1.5          0.1      Iris-setosa
# 10           5.4          3.7           1.5          0.2      Iris-setosa
# 11           4.8          3.4           1.6          0.2      Iris-setosa
# ...

# %%
# conver categorical data to numerical using label encodding: 
label_encoder = preprocessing.LabelEncoder()
iris['species'] = label_encoder.fit_transform(iris['species'])
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
# split the data :
x = iris.iloc[:,0:4]
y = iris.iloc[:,4]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=50)
# x_train.shape

# %%
# C5.0 :
model = DecisionTreeClassifier(criterion='entropy', max_depth=3)
model.fit(x_train, y_train)
tree.plot_tree(model)
# Out:
# [Text(0.375, 0.875, 'X[2] <= 2.45\nentropy = 1.584\nsamples = 120\nvalue = [41, 38, 41]'),
#  Text(0.25, 0.625, 'entropy = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.5, 0.625, 'X[3] <= 1.65\nentropy = 0.999\nsamples = 79\nvalue = [0, 38, 41]'),
#  Text(0.25, 0.375, 'X[2] <= 4.95\nentropy = 0.461\nsamples = 41\nvalue = [0, 37, 4]'),
#  Text(0.125, 0.125, 'entropy = 0.0\nsamples = 36\nvalue = [0, 36, 0]'),
#  Text(0.375, 0.125, 'entropy = 0.722\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(0.75, 0.375, 'X[2] <= 4.85\nentropy = 0.176\nsamples = 38\nvalue = [0, 1, 37]'),
#  Text(0.625, 0.125, 'entropy = 0.811\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.875, 0.125, 'entropy = 0.0\nsamples = 34\nvalue = [0, 0, 34]')]

# %%
fn = ["sepal_length", "sepal_width", "petal_length", "petal_width"]
cn = ["setosa", "versicolor", "virginica"]
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(4,4), dpi=300)
tree.plot_tree(model, feature_names=fn, class_names = cn, filled=True)
# Out:
# [Text(0.375, 0.875, 'petal_length <= 2.45\nentropy = 1.584\nsamples = 120\nvalue = [41, 38, 41]\nclass = setosa'),
#  Text(0.25, 0.625, 'entropy = 0.0\nsamples = 41\nvalue = [41, 0, 0]\nclass = setosa'),
#  Text(0.5, 0.625, 'petal_width <= 1.65\nentropy = 0.999\nsamples = 79\nvalue = [0, 38, 41]\nclass = virginica'),
#  Text(0.25, 0.375, 'petal_length <= 4.95\nentropy = 0.461\nsamples = 41\nvalue = [0, 37, 4]\nclass = versicolor'),
#  Text(0.125, 0.125, 'entropy = 0.0\nsamples = 36\nvalue = [0, 36, 0]\nclass = versicolor'),
#  Text(0.375, 0.125, 'entropy = 0.722\nsamples = 5\nvalue = [0, 1, 4]\nclass = virginica'),
#  Text(0.75, 0.375, 'petal_length <= 4.85\nentropy = 0.176\nsamples = 38\nvalue = [0, 1, 37]\nclass = virginica'),
#  Text(0.625, 0.125, 'entropy = 0.811\nsamples = 4\nvalue = [0, 1, 3]\nclass = virginica'),
#  Text(0.875, 0.125, 'entropy = 0.0\nsamples = 34\nvalue = [0, 0, 34]\nclass = virginica')]

# %%
pred = model.predict(x_test)
pd.Series(pred).value_counts()
# Out:
# 1    11
# 2    10
# 0     9
# dtype: int64

# %%
# to check accuracy score :
import numpy as np
np.mean(pred==y_test)           # 0.96667
pd.crosstab(y_test, pred)
# Out:
# col_0    0   1  2
# species
# 0        9   0  0
# 1        0  11  1
# 2        0   0  9

# %%
# CART (classification and regression tree) :
# for classification :
model_gini = DecisionTreeClassifier(criterion='gini', max_depth=3)
model_gini.fit(x_train, y_train)
gini_pred = model_gini.predict(x_test)
pd.Series(gini_pred).value_counts()
np.mean(y_test==gini_pred)     # 0.966667
# Out:
# 0.9666666666666667

# %%
# DecisionTree for Regression :
array = iris.values
# here we cant take categorical columns (species) so we try to predict petal_width :
x_new = array[:,0:3]
y_new = array[:,3]
x_new_train, x_new_test, y_new_train, y_new_test = train_test_split(x_new, y_new, test_size=0.3, random_state=40)
# x_new_train.shape                          # (105, 3)

# %%
# make model for regression and fit :
reg_model = DecisionTreeRegressor()
reg_model.fit(x_new_train, y_new_train)
reg_model.score(x_new_train, y_new_train)             # 0.999665
reg_pred = reg_model.predict(x_new_test)
pd.crosstab(reg_pred, y_new_test)
np.mean(reg_pred==y_new_test)                    # 0.222
# Out:
# 0.2222222222222222
